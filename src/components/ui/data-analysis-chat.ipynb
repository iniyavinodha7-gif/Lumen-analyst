# %% [markdown]
# # Data Analysis Chat
#
# Exported from Lumen — Conversational Data Analyst.

# %%
import pandas as pd, numpy as np

df = pd.read_csv("your_dataset.csv")
df.head()

# %% [markdown]
# **Question:** hiii

# %% [markdown]
# Hello there! I'm your friendly data analyst. I can help you explore, understand, and visualize your data.
#
# To get started, you can load a dataset. Do you have a CSV or an Excel file you'd like to analyze today?

# %% [markdown]
# **Question:** hiii

# %% [markdown]
# Hello there! I'm your friendly data analyst. I can help you explore, understand, and visualize your data.
#
# To get started, you can load a dataset. Do you have a CSV or an Excel file you'd like to analyze today?

# %% [markdown]
# **Question:** what are you doing?

# %% [markdown]
# I'm currently waiting for you to upload a dataset! Once you do, I can help you analyze it, find interesting patterns, and even create some visualizations. Think of me as your personal data assistant. What kind of data are you working with today?
